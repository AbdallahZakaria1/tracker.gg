# %% [markdown]
# # Recuperation des pseudos et des Hastags

# %%
import requests
from bs4 import BeautifulSoup

def top10k(n):
    rq = requests.get(f"https://tracker.gg/valorant/leaderboards/ranked/all/default?page={n}&region=global&act=4401f9fd-4170-2e4c-4bc3-f3b4d7d150d1")

    soup = BeautifulSoup(rq.text )

    pseudo = soup.findAll('span', class_='trn-ign__username')
    Hastag = soup.findAll('span', class_='trn-ign__discriminator')
    pseudo_Hastag = []
    #Hastag sans #:
    Hastag1 = [i.text.strip() for i in Hastag]
    Hastag_sans_hastag =[]
    for i in Hastag1:
        Hastag_sans_hastag.append(i.strip("#"))
    for i in range(len(pseudo)):
        pseudo_Hastag.append([pseudo[i].text.strip(),Hastag_sans_hastag[i]])
    return pseudo_Hastag

# %% [markdown]
# # Donné du top 100 recuperer le 07/11 a 3h du matin

# %%
pseudo_Hastag = [['INC westside', 'uwu'], ['Darxcio', '1TAP'], ['è\x99\x8eç\x89\x99 cxy0714', '0714'], ['PMT Movi', '16yo'], ['TTV CRUNCH', 'VAL'], ['UNFAKE', 'xlo'], ['Sayonara', 'Karel'], ['Gold D Surf', '0505'], ['EX0 pyrolll', 'xws'], ['maverick', 'S2L'], ['Mercure', 'LP1'], ['MICKNUTTY333', 'meow'], ['Lanerinno', '8014'], ['BabyJ', 'Halo'], ['Wolverine', '715'], ['6ankai THE F', '666'], ['tkzin', 'alone'], ['BLEED skeleton', '66666'], ['chase', '2404'], ['Askia', 'kaah'], ['VEX ind', '999'], ['ianto', 'aim'], ['MZP Martux', 'meow'], ['acrian', '420'], ['friendly krm', '000'], ['babybaby', 'bay'], ['OR Paincakes', '1738'], ['DavidObRaZiL', '444'], ['B1RDMAN', '4fun'], ['batujnax å«\x8cã\x81\x84', '2005'], ['Samuraj', 'hardy'], ['cactus', '3266'], ['LeeoLoos', 'Pittu'], ['MANIEK', '11111'], ['PRX f0rsakeN', 'mave'], ['PRX something', '112'], ['dddddddddddddddd', '224'], ['XÃ©rox', '777'], ['pryze', 'budy'], ['PRX SkRossi', 'moose'], ['twitch furbsa', 'cam'], ['Fire', 'James'], ['griffithz', '1738'], ['starkk', '123'], ['LOFI MihLog', '2303'], ['fred', 'wwwww'], ['P0PPIN', '4529'], ['ACE FakeAnanas', 'TTV'], ['Kaaan', '1337'], ['Kanpeki', '1111'], ['lz ã\x83¡', '2003'], ['Kubfu', 'Slay'], ['RBTE KATU', '23KK'], ['Necro', 'DINK'], ['FOKUS Fizzy', '0311'], ['GEN t3xture', '9999'], ['Eggsterr', 'NJLTC'], ['ALT s0pp', 'swag'], ['FS Virtyy', '503'], ['JaimeLesGlaces', 'CCLES'], ['gosaydam', '0707'], ['PCF LÃªwN', 'SBA'], ['SEN Sacy', 'moba'], ['SKÃ\x85L daki', 'alya'], ['DRG Shion7', 'wsy7'], ['Stix', 'layss'], ['furqRomantico', 'nini'], ['dedmos', '333'], ['McClapped', 'SERB'], ['T1 MUNCHKIN', '0327'], ['gbzz', 'lglg'], ['TSM Subroza', '4678'], ['Dani', 'DDDDD'], ['PRX primmie', 'dream'], ['Ease', '2323'], ['Kaban4ik', '777'], ['yukidudebeabadoo', 'dude'], ['dominic', '043'], ['SthZ', 'Goat'], ['swzin', '2002'], ['ElysiumXYZ', 'Kaya'], ['Jefesin', '0000'], ['stinky', '4201'], ['miracle', 'aigyr'], ['BBL AsLanM4shadW', 'AsLan'], ['TTV DisordedTV', '1234'], ['RA stew', 'Xer'], ['EG BcJ', '5FT2'], ['d3murrr', 'ari'], ['mishu', 'frog'], ['Loumac', 'main'], ['Zinx', 'TTV'], ['vCan', '666'], ['NotDesare', 'tyzer'], ['iXeonN', 'keen'], ['BladeZ', 'catyz'], ['Mofcon', 'KiX'], ['req', 'oppaÃ\xad'], ['BB SID', 'BBWIN'], ['1245234512345156', '2345']]

# %% [markdown]
# # Recuperation des Information D'un joueur

# %%
import time



def info_Dunjoueur(pseudo,hastag):
    url = f"https://tracker.gg/valorant/profile/riot/{pseudo}%23{hastag}/overview"
    rq = requests.get(url)
    soup = BeautifulSoup(rq.text)
    info =soup.findAll('span', class_='value')
    info_joueur = []
    if len(info) >= 3:
        info.pop(0)
        info.pop(0)
        info.pop(0)

    info_joueur.append(pseudo)
    info_joueur.append(hastag)
    for i in range(len(info)):

        info_joueur.append(info[i].text.strip())
    return info_joueur


def verification(pseudo,hastag):
    url = f"https://tracker.gg/valorant/profile/riot/{pseudo}%23{hastag}/overview"
    rq = requests.get(url)
    if rq.status_code == 200:
        return 1
    else:
        return 0

# %%
info_Dunjoueur("AZKR","9228")
# Out:
# ['AZKR',
#  '9228',
#  '126.4',
#  '0.92',
#  '22.9%',
#  '51.4%',
#  '71',
#  '68.0%',
#  '-22',
#  '1,944',
#  '2,119',
#  '587',
#  '195.0',
#  '1.19',
#  '0.7',
#  '289',
#  '104',
#  '3']

# %%
donne_csv = []
import time
for i in pseudo_Hastag:
    
    code = verification(i[0],i[1])
    if code == 1:
        info = info_Dunjoueur(i[0],i[1])
        donne_csv.append(info)
    time.sleep(10)

# %% [markdown]
# # Donné du top 100 recuperer le 07/11 a 3h du matin

# %%
donne_csv = [['INC westside', 'uwu', '166.2', '1.29', '39.6%', '66.2%', '43', '74.7%', '32', '1,217', '940', '251', '247.4', '1.56', '0.9', '180', '57', '4'], ['Darxcio', '1TAP', '168.9', '1.16', '41.2%', '55.4%', '56', '70.0%', '17', '1,973', '1,702', '324', '258.9', '1.35', '0.9', '372', '59', '4'], ['PMT Movi', '16yo', '153.3', '1.17', '30.4%', '62.3%', '48', '75.0%', '25', '1,295', '1,110', '503', '228.3', '1.62', '0.8', '131', '66', '2'], ['TTV CRUNCH', 'VAL', '157.5', '1.18', '39.9%', '63.9%', '53', '73.6%', '15', '1,491', '1,267', '328', '240.9', '1.44', '0.9', '218', '59', '2'], ['UNFAKE', 'xlo', '153.8', '1.19', '37.6%', '65.6%', '42', '75.8%', '25', '1,101', '928', '351', '226.3', '1.56', '0.8', '113', '58', '0'], ['Sayonara', 'Karel', '179.3', '1.29', '40.7%', '57.5%', '50', '71.7%', '34', '1,775', '1,378', '305', '275.2', '1.51', '1.0', '363', '78', '8'], ['Gold D Surf', '0505', '181.6', '1.41', '38.9%', '61.0%', '50', '72.5%', '40', '1,764', '1,255', '274', '281.5', '1.62', '1.0', '340', '
.9%', '9', '798', '746', '236', '217.3', '1.39', '0.8', '113', '47', '1'], ['Loumac', 'main', '147.9', '1.00', '23.1%', '61.9%', '39', '69.0%', '1', '974', '976', '325', '220.0', '1.33', '0.8', '169', '38', '1'], ['Zinx', 'TTV', '167.7', '1.09', '26.8%', '50.8%', '32', '70.9%', '19', '1,168', '1,067', '360', '249.2', '1.43', '0.8', '164', '43', '5'], ['vCan', '666', '146.7', '1.05', '24.7%', '57.8%', '26', '71.7%', '13', '714', '678', '261', '213.2', '1.44', '0.7', '81', '40', '1'], ['NotDesare', 'tyzer', '134.2', '1.14', '39.0%', '56.0%', '28', '74.2%', '13', '757', '666', '238', '197.6', '1.49', '0.7', '61', '30', '0'], ['iXeonN', 'keen', '151.2', '1.10', '29.5%', '64.1%', '25', '74.2%', '8', '680', '621', '176', '229.4', '1.38', '0.8', '139', '48', '0'], ['BladeZ', 'catyz', '162.1', '1.18', '32.4%', '50.8%', '30', '72.5%', '22', '1,076', '912', '265', '241.9', '1.47', '0.8', '175', '52', '2'], ['Mofcon', 'KiX', '121.0', '0.95', '38.3%', '48.3%', '42', '70.2%', '-9', '1,235', '1,305', '486', '183.0', '1.32', '0.7', '112', '77', '3'], ['BB SID', 'BBWIN', '159.7', '1.14', '37.6%', '59.6%', '28', '70.7%', '18', '882', '771', '166', '242.2', '1.36', '0.9', '191', '47', '1'], ['1245234512345156', '2345', '163.8', '1.19', '27.7%', '51.9%', '28', '72.6%', '25', '1,043', '876', '240', '249.6', '1.46', '0.9', '172', '54', '3'],]

# %%
import numpy as np
import pandas as pd
array = np.array(donne_csv)
X = pd.DataFrame(data = array)
X.columns = ["Pseudo","hastag","Damage/Round","K/D Ratio","Headshot%","Win %","Wins","KAST","DDÎ/Round","Kills","Deaths","Assists","ACS","KAD Ratio","Kills/Round","First Bloods","Flawless","Aces"]

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# credit : https://www.journaldunet.fr/developpeur/developpement/1497437-comment-obtenir-tous-les-noms-de-colonnes-d-une-dataframe-pandas/#:~:text=Pour%20obtenir%20les%20colonnes%20d,d%C3%A9faut%20qu'un%20r%C3%A9sultat%20partiel.&text=Pour%20afficher%20la%20totalit%C3%A9%20des,param%C3%A8tres%20de%20la%20librairie%20Pandas.

# %%
X
# Out:
#               Pseudo hastag Damage/Round K/D Ratio Headshot%  Win % Wins  \
# 0       INC westside    uwu        163.3      1.21     38.7%  56.7%   51
# 1            Darxcio   1TAP        167.1      1.15     41.2%  55.0%   60
# 2           PMT Movi   16yo        152.3      1.16     31.1%  60.0%   60
# 3         TTV CRUNCH    VAL        153.3      1.13     38.8%  56.8%   67
# 4             UNFAKE    xlo        154.0      1.19     38.1%  67.5%   54
# 5           Sayonara  Karel        177.7      1.28     40.3%  59.6%   65
# 6        Gold D Surf   0505        175.4      1.36     36.7%  63.7%   79
# 7        EX0 pyrolll    xws        179.3      1.48     37.8%  72.7%   48
# 8           maverick    S2L        138.7      1.09     26.8%  60.0%   60
# 9            Mercure    LP1        166.9      1.26     38.2%  60.4%   58
# 10      MICKNUTTY333   meow        131.3      0.96     29.0%  58.0%   58
# 11         Lanerinno   8014        152.4      1.15     30.7%  64.7%   55
# ...
